# %% [markdown]
# # Reading in files

# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\Rishi\Downloads\countries of the world.csv")
df
# pd.read_csv(r"C:\Users\Rishi\Downloads\countries of the world.csv", header = None, names = ['Country','Region'])   ?= if we don't have headers
# Out:
#              Country                               Region
# 0       Afghanistan         ASIA (EX. NEAR EAST)
# 1           Albania   EASTERN EUROPE
# 2           Algeria   NORTHERN AFRICA
# 3    American Samoa   OCEANIA
# 4           Andorra   WESTERN EUROPE
# ..               ...                                  ...
# 222       West Bank   NEAR EAST
# 223  Western Sahara   NORTHERN AFRICA
# 224           Yemen   NEAR EAST
# 225          Zambia   SUB-SAHARAN AFRICA
# 226        Zimbabwe   SUB-SAHARAN AFRICA
#
# [227 rows x 2 columns]

# %%
pd.set_option('display.max.row', 235)  # if we want to read all the file
#pd.set_option('display.max.columns', 40)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 227 entries, 0 to 226
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Country  227 non-null    object
#  1   Region   227 non-null    object
# dtypes: object(2)
# memory usage: 3.7+ KB

# %%
df.shape   # rows and columns
# Out:
# (227, 2)

# %%
df.head(6)
# Out:
#            Country                               Region
# 0     Afghanistan         ASIA (EX. NEAR EAST)
# 1         Albania   EASTERN EUROPE
# 2         Algeria   NORTHERN AFRICA
# 3  American Samoa   OCEANIA
# 4         Andorra   WESTERN EUROPE
# 5          Angola   SUB-SAHARAN AFRICA

# %%
df.tail(2)
# Out:
#        Country                               Region
# 225    Zambia   SUB-SAHARAN AFRICA
# 226  Zimbabwe   SUB-SAHARAN AFRICA

# %%
df['Country']
# Out:
# 0                           Afghanistan
# 1                               Albania
# 2                               Algeria
# 3                        American Samoa
# 4                               Andorra
# 5                                Angola
# 6                              Anguilla
# 7                     Antigua & Barbuda
# 8                             Argentina
# 9                               Armenia
# 10                                Aruba
# 11                            Australia
# 12                              Austria
# 13                           Azerbaijan
# 14                         Bahamas, The
# 15                              Bahrain
# 16                           Bangladesh
# 17                             Barbados
# 18                              Belarus
# 19                              Belgium
# 20                               Belize
# 21                                Benin
# 22                              Bermuda
# ...

# %%
df.loc[221]
# Out:
# Country                     Wallis and Futuna
# Region     OCEANIA
# Name: 221, dtype: object

# %%
df.iloc[221]
# Out:
# Country                     Wallis and Futuna
# Region     OCEANIA
# Name: 221, dtype: object

# %% [markdown]
# # Filtering

# %%
dff =  pd.read_csv(r"C:\Users\Rishi\Downloads\world_population.csv")
dff
# Out:
#      Rank CCA3                           Country              Capital  \
# 0      36  AFG                       Afghanistan                Kabul
# 1     138  ALB                           Albania               Tirana
# 2      34  DZA                           Algeria              Algiers
# 3     213  ASM                    American Samoa            Pago Pago
# 4     203  AND                           Andorra     Andorra la Vella
# 5      42  AGO                            Angola               Luanda
# 6     224  AIA                          Anguilla           The Valley
# 7     201  ATG               Antigua and Barbuda         Saint John’s
# 8      33  ARG                         Argentina         Buenos Aires
# 9     140  ARM                           Armenia              Yerevan
# 10    198  ABW                             Aruba           Oranjestad
# 11     55  AUS                         Australia             Canberra
# ...

# %%
dff[dff['Rank'] <= 10]
# Out:
#      Rank CCA3        Country           Capital      Continent  \
# 16      8  BGD     Bangladesh             Dhaka           Asia
# 27      7  BRA         Brazil          Brasilia  South America
# 41      1  CHN          China           Beijing           Asia
# 92      2  IND          India         New Delhi           Asia
# 93      4  IDN      Indonesia           Jakarta           Asia
# 131    10  MEX         Mexico       Mexico City  North America
# 149     6  NGA        Nigeria             Abuja         Africa
# 156     5  PAK       Pakistan         Islamabad           Asia
# 171     9  RUS         Russia            Moscow         Europe
# 221     3  USA  United States  Washington, D.C.  North America
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 16      1.711864e+08     1.674210e+08     1.578300e+08     1.483911e+08
# 27      2.153135e+08     2.131963e+08     2.051882e+08     1.963535e+08
# ...

# %%
specific_countrues = ['Bangladesh','Brazil']
dff[dff['Country'].isin(specific_countrues)]
# Out:
#     Rank CCA3     Country   Capital      Continent  2022 Population  \
# 16     8  BGD  Bangladesh     Dhaka           Asia      171186372.0
# 27     7  BRA      Brazil  Brasilia  South America      215313498.0
#
#     2020 Population  2015 Population  2010 Population  2000 Population  \
# 16      167420951.0      157830000.0      148391139.0      129193327.0
# 27      213196304.0      205188205.0      196353492.0      175873720.0
#
#     1990 Population  1980 Population  1970 Population  Area (km²)  \
# 16      107147651.0       83929765.0       67541860.0    147570.0
# 27      150706446.0      122288383.0       96369875.0   8515767.0
#
#     Density (per km²)  Growth Rate  World Population Percentage
# 16          1160.0350       1.0108                         2.15
# 27            25.2841       1.0046                         2.70

# %%
dff[dff['Country'].str.contains('United')]
# Out:
#      Rank CCA3                       Country           Capital      Continent  \
# 219    97  ARE          United Arab Emirates         Abu Dhabi           Asia
# 220    21  GBR                United Kingdom            London         Europe
# 221     3  USA                 United States  Washington, D.C.  North America
# 222   200  VIR  United States Virgin Islands  Charlotte Amalie  North America
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 219        9441129.0        9287289.0        8916899.0        8481771.0
# 220       67508936.0       67059474.0       65224364.0       62760039.0
# 221      338289857.0      335942003.0      324607776.0      311182845.0
# 222          99465.0         100442.0         102803.0         106142.0
#
#      2000 Population  1990 Population  1980 Population  1970 Population  \
# 219        3275333.0        1900151.0        1014048.0         298084.0
# ...

# %%
dff2 = dff.set_index('Country')
dff2
# Out:
#                                   Rank CCA3              Capital  \
# Country
# Afghanistan                         36  AFG                Kabul
# Albania                            138  ALB               Tirana
# Algeria                             34  DZA              Algiers
# American Samoa                     213  ASM            Pago Pago
# Andorra                            203  AND     Andorra la Vella
# Angola                              42  AGO               Luanda
# Anguilla                           224  AIA           The Valley
# Antigua and Barbuda                201  ATG         Saint John’s
# Argentina                           33  ARG         Buenos Aires
# Armenia                            140  ARM              Yerevan
# Aruba                              198  ABW           Oranjestad
# Australia                           55  AUS             Canberra
# Austria                             99  AUT               Vienna
# ...

# %%
dff2.filter(items = ['Continent','CCA3'], axis = 1)
# Out:
#                                       Continent CCA3
# Country
# Afghanistan                                Asia  AFG
# Albania                                  Europe  ALB
# Algeria                                  Africa  DZA
# American Samoa                          Oceania  ASM
# Andorra                                  Europe  AND
# Angola                                   Africa  AGO
# Anguilla                          North America  AIA
# Antigua and Barbuda               North America  ATG
# Argentina                         South America  ARG
# Armenia                                    Asia  ARM
# Aruba                             North America  ABW
# Australia                               Oceania  AUS
# Austria                                  Europe  AUT
# Azerbaijan                                 Asia  AZE
# Bahamas                           North America  BHS
# Bahrain                                    Asia  BHR
# Bangladesh                                 Asia  BGD
# ...

# %%
dff2.filter(items = ['Zimbabwe'], axis = 0)
# Out:
#           Rank CCA3 Capital Continent  2022 Population  2020 Population  \
# Country
# Zimbabwe    74  ZWE  Harare    Africa       16320537.0       15669666.0
#
#           2015 Population  2010 Population  2000 Population  1990 Population  \
# Country
# Zimbabwe       14154937.0       12839771.0       11834676.0       10113893.0
#
#           1980 Population  1970 Population  Area (km²)  Density (per km²)  \
# Country
# Zimbabwe        7049926.0        5202918.0    390757.0            41.7665
#
#           Growth Rate  World Population Percentage
# Country
# Zimbabwe       1.0204                          0.2

# %%
dff2.filter(like = 'United', axis = 0)
# Out:
#                               Rank CCA3           Capital      Continent  \
# Country
# United Arab Emirates            97  ARE         Abu Dhabi           Asia
# United Kingdom                  21  GBR            London         Europe
# United States                    3  USA  Washington, D.C.  North America
# United States Virgin Islands   200  VIR  Charlotte Amalie  North America
#
#                               2022 Population  2020 Population  \
# Country
# United Arab Emirates                9441129.0        9287289.0
# United Kingdom                     67508936.0       67059474.0
# United States                     338289857.0      335942003.0
# United States Virgin Islands          99465.0         100442.0
#
#                               2015 Population  2010 Population  \
# Country
# United Arab Emirates                8916899.0        8481771.0
# United Kingdom                     65224364.0       62760039.0
# ...

# %%
dff2.loc['United States']
# Out:
# Rank                                          3
# CCA3                                        USA
# Capital                        Washington, D.C.
# Continent                         North America
# 2022 Population                     338289857.0
# 2020 Population                     335942003.0
# 2015 Population                     324607776.0
# 2010 Population                     311182845.0
# 2000 Population                     282398554.0
# 1990 Population                     248083732.0
# 1980 Population                     223140018.0
# 1970 Population                     200328340.0
# Area (km²)                            9372610.0
# Density (per km²)                       36.0935
# Growth Rate                              1.0038
# World Population Percentage                4.24
# Name: United States, dtype: object

# %%
dff2.iloc[4]
# Out:
# Rank                                        203
# CCA3                                        AND
# Capital                        Andorra la Vella
# Continent                                Europe
# 2022 Population                         79824.0
# 2020 Population                         77700.0
# 2015 Population                         71746.0
# 2010 Population                         71519.0
# 2000 Population                         66097.0
# 1990 Population                         53569.0
# 1980 Population                         35611.0
# 1970 Population                         19860.0
# Area (km²)                                468.0
# Density (per km²)                      170.5641
# Growth Rate                                1.01
# World Population Percentage                 0.0
# Name: Andorra, dtype: object

# %% [markdown]
# # Order by

# %%
dff[dff['Rank'] < 10].sort_values(by='Rank',ascending=False)
# Out:
#      Rank CCA3        Country           Capital      Continent  \
# 171     9  RUS         Russia            Moscow         Europe
# 16      8  BGD     Bangladesh             Dhaka           Asia
# 27      7  BRA         Brazil          Brasilia  South America
# 149     6  NGA        Nigeria             Abuja         Africa
# 156     5  PAK       Pakistan         Islamabad           Asia
# 93      4  IDN      Indonesia           Jakarta           Asia
# 221     3  USA  United States  Washington, D.C.  North America
# 92      2  IND          India         New Delhi           Asia
# 41      1  CHN          China           Beijing           Asia
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 171     1.447133e+08     1.456173e+08     1.446684e+08     1.432426e+08
# 16      1.711864e+08     1.674210e+08     1.578300e+08     1.483911e+08
# 27      2.153135e+08     2.131963e+08     2.051882e+08     1.963535e+08
# ...

# %%
dff[dff['Rank'] < 10].sort_values(by=['Country','Rank'],ascending=True)
# Out:
#      Rank CCA3        Country           Capital      Continent  \
# 16      8  BGD     Bangladesh             Dhaka           Asia
# 27      7  BRA         Brazil          Brasilia  South America
# 41      1  CHN          China           Beijing           Asia
# 92      2  IND          India         New Delhi           Asia
# 93      4  IDN      Indonesia           Jakarta           Asia
# 149     6  NGA        Nigeria             Abuja         Africa
# 156     5  PAK       Pakistan         Islamabad           Asia
# 171     9  RUS         Russia            Moscow         Europe
# 221     3  USA  United States  Washington, D.C.  North America
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 16      1.711864e+08     1.674210e+08     1.578300e+08     1.483911e+08
# 27      2.153135e+08     2.131963e+08     2.051882e+08     1.963535e+08
# 41      1.425887e+09     1.424930e+09     1.393715e+09     1.348191e+09
# ...

# %% [markdown]
# # Indexing

# %%
dff
# Out:
#      Rank CCA3                           Country              Capital  \
# 0      36  AFG                       Afghanistan                Kabul
# 1     138  ALB                           Albania               Tirana
# 2      34  DZA                           Algeria              Algiers
# 3     213  ASM                    American Samoa            Pago Pago
# 4     203  AND                           Andorra     Andorra la Vella
# 5      42  AGO                            Angola               Luanda
# 6     224  AIA                          Anguilla           The Valley
# 7     201  ATG               Antigua and Barbuda         Saint John’s
# 8      33  ARG                         Argentina         Buenos Aires
# 9     140  ARM                           Armenia              Yerevan
# 10    198  ABW                             Aruba           Oranjestad
# 11     55  AUS                         Australia             Canberra
# ...

# %%
dff =  pd.read_csv(r"C:\Users\Rishi\Downloads\world_population.csv", index_col = 'Country')
dff
# Out:
#                                   Rank CCA3              Capital  \
# Country
# Afghanistan                         36  AFG                Kabul
# Albania                            138  ALB               Tirana
# Algeria                             34  DZA              Algiers
# American Samoa                     213  ASM            Pago Pago
# Andorra                            203  AND     Andorra la Vella
# Angola                              42  AGO               Luanda
# Anguilla                           224  AIA           The Valley
# Antigua and Barbuda                201  ATG         Saint John’s
# Argentina                           33  ARG         Buenos Aires
# Armenia                            140  ARM              Yerevan
# Aruba                              198  ABW           Oranjestad
# Australia                           55  AUS             Canberra
# Austria                             99  AUT               Vienna
# ...

# %%
dff.reset_index(inplace=True)

# %%
dff
# Out:
#                               Country  Rank CCA3              Capital  \
# 0                         Afghanistan    36  AFG                Kabul
# 1                             Albania   138  ALB               Tirana
# 2                             Algeria    34  DZA              Algiers
# 3                      American Samoa   213  ASM            Pago Pago
# 4                             Andorra   203  AND     Andorra la Vella
# 5                              Angola    42  AGO               Luanda
# 6                            Anguilla   224  AIA           The Valley
# 7                 Antigua and Barbuda   201  ATG         Saint John’s
# 8                           Argentina    33  ARG         Buenos Aires
# 9                             Armenia   140  ARM              Yerevan
# 10                              Aruba   198  ABW           Oranjestad
# 11                          Australia    55  AUS             Canberra
# ...

# %%
dff.set_index('Country', inplace = True)

# %%
dff
# Out:
#                                   Rank CCA3              Capital  \
# Country
# Afghanistan                         36  AFG                Kabul
# Albania                            138  ALB               Tirana
# Algeria                             34  DZA              Algiers
# American Samoa                     213  ASM            Pago Pago
# Andorra                            203  AND     Andorra la Vella
# Angola                              42  AGO               Luanda
# Anguilla                           224  AIA           The Valley
# Antigua and Barbuda                201  ATG         Saint John’s
# Argentina                           33  ARG         Buenos Aires
# Armenia                            140  ARM              Yerevan
# Aruba                              198  ABW           Oranjestad
# Australia                           55  AUS             Canberra
# Austria                             99  AUT               Vienna
# ...

# %%
dff.iloc[[2,7,8]]
# Out:
#                      Rank CCA3       Capital      Continent  2022 Population  \
# Country
# Algeria                34  DZA       Algiers         Africa       44903225.0
# Antigua and Barbuda   201  ATG  Saint John’s  North America          93763.0
# Argentina              33  ARG  Buenos Aires  South America       45510318.0
#
#                      2020 Population  2015 Population  2010 Population  \
# Country
# Algeria                   43451666.0       39543154.0       35856344.0
# Antigua and Barbuda          92664.0          89941.0          85695.0
# Argentina                 45036032.0       43257065.0       41100123.0
#
#                      2000 Population  1990 Population  1980 Population  \
# Country
# Algeria                   30774621.0       25518074.0       18739378.0
# Antigua and Barbuda          75055.0          63328.0          64888.0
# Argentina                 37070774.0       32637657.0       28024803.0
#
# ...

# %%
dff.iloc[2]
# Out:
# Rank                                   34
# CCA3                                  DZA
# Capital                           Algiers
# Continent                          Africa
# 2022 Population                44903225.0
# 2020 Population                43451666.0
# 2015 Population                39543154.0
# 2010 Population                35856344.0
# 2000 Population                30774621.0
# 1990 Population                25518074.0
# 1980 Population                18739378.0
# 1970 Population                13795915.0
# Area (km²)                      2381741.0
# Density (per km²)                 18.8531
# Growth Rate                        1.0164
# World Population Percentage          0.56
# Name: Algeria, dtype: object

# %%
dff.reset_index(inplace=True)

# %%
dff.set_index(['Continent','Country'], inplace = True)
dff
# Out:
#                                                 Rank CCA3  \
# Continent     Country
# Asia          Afghanistan                         36  AFG
# Europe        Albania                            138  ALB
# Africa        Algeria                             34  DZA
# Oceania       American Samoa                     213  ASM
# Europe        Andorra                            203  AND
# Africa        Angola                              42  AGO
# North America Anguilla                           224  AIA
#               Antigua and Barbuda                201  ATG
# South America Argentina                           33  ARG
# Asia          Armenia                            140  ARM
# North America Aruba                              198  ABW
# Oceania       Australia                           55  AUS
# Europe        Austria                             99  AUT
# Asia          Azerbaijan                          91  AZE
# North America Bahamas                            176  BHS
# ...

# %%
dff.sort_index(ascending = True)

#pd.set_option('display.max.columns', 235)
# Out:
#                                                 Rank CCA3  \
# Continent     Country
# Africa        Algeria                             34  DZA
#               Angola                              42  AGO
#               Benin                               77  BEN
#               Botswana                           144  BWA
#               Burkina Faso                        58  BFA
#               Burundi                             78  BDI
#               Cameroon                            53  CMR
#               Cape Verde                         171  CPV
#               Central African Republic           117  CAF
#               Chad                                69  TCD
#               Comoros                            163  COM
#               DR Congo                            15  COD
#               Djibouti                           160  DJI
#               Egypt                               14  EGY
#               Equatorial Guinea                  152  GNQ
# ...

# %%
dff.loc['Africa','Angola']
# Out:
# Rank                                   42
# CCA3                                  AGO
# Capital                            Luanda
# 2022 Population                35588987.0
# 2020 Population                33428485.0
# 2015 Population                28127721.0
# 2010 Population                23364185.0
# 2000 Population                16394062.0
# 1990 Population                11828638.0
# 1980 Population                 8330047.0
# 1970 Population                 6029700.0
# Area (km²)                      1246700.0
# Density (per km²)                 28.5466
# Growth Rate                        1.0315
# World Population Percentage          0.45
# Name: (Africa, Angola), dtype: object

# %%
dff.iloc[1]
# Out:
# Rank                                 138
# CCA3                                 ALB
# Capital                           Tirana
# 2022 Population                2842321.0
# 2020 Population                2866849.0
# 2015 Population                2882481.0
# 2010 Population                2913399.0
# 2000 Population                3182021.0
# 1990 Population                3295066.0
# 1980 Population                2941651.0
# 1970 Population                2324731.0
# Area (km²)                       28748.0
# Density (per km²)                98.8702
# Growth Rate                       0.9957
# World Population Percentage         0.04
# Name: (Europe, Albania), dtype: object

# %% [markdown]
# # Group by and Aggregating

# %%
dt = pd.read_csv(r"C:\Users\Rishi\Downloads\Flavors.csv")

# %%
dt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Flavor          9 non-null      object
#  1   Base Flavor     9 non-null      object
#  2   Liked           9 non-null      object
#  3   Flavor Rating   9 non-null      float64
#  4   Texture Rating  9 non-null      float64
#  5   Total Rating    9 non-null      float64
# dtypes: float64(3), object(3)
# memory usage: 564.0+ bytes

# %%
 #dt.groupby('Total Rating').mean()              #

# %%
dt.groupby('Base Flavor').count()
# Out:
#              Flavor  Liked  Flavor Rating  Texture Rating  Total Rating
# Base Flavor
# Chocolate         3      3              3               3             3
# Vanilla           6      6              6               6             6

# %%
dt.groupby('Base Flavor').min()
# Out:
#                   Flavor Liked  Flavor Rating  Texture Rating  Total Rating
# Base Flavor
# Chocolate      Chocolate   Yes            8.2             7.0          15.2
# Vanilla      Cake Batter    No            2.3             3.4           5.7

# %%
dt.groupby('Base Flavor').max()
# Out:
#                  Flavor Liked  Flavor Rating  Texture Rating  Total Rating
# Base Flavor
# Chocolate    Rocky Road   Yes            8.8             7.6          16.6
# Vanilla         Vanilla   Yes           10.0             8.0          18.0

# %%
dt.groupby('Base Flavor').sum()
# Out:
#                                                         Flavor  \
# Base Flavor
# Chocolate            ChocolateRocky RoadChocolte Fudge Brownie
# Vanilla      Mint Chocolate ChipVanillaCookie DoughPistachi...
#
#                        Liked  Flavor Rating  Texture Rating  Total Rating
# Base Flavor
# Chocolate          YesYesYes           25.2            21.7          47.1
# Vanilla      YesNoYesNoYesNo           34.2            33.9          68.1

# %%
dt.groupby('Base Flavor').agg({'Flavor Rating': ['max','count','sum','mean'], 'Texture Rating': ['max','count','sum','mean']})
# Out:
#             Flavor Rating                  Texture Rating              \
#                       max count   sum mean            max count   sum
# Base Flavor
# Chocolate             8.8     3  25.2  8.4            7.6     3  21.7
# Vanilla              10.0     6  34.2  5.7            8.0     6  33.9
#
#
#                  mean
# Base Flavor
# Chocolate    7.233333
# Vanilla      5.650000

# %%
dt
# Out:
#                    Flavor Base Flavor Liked  Flavor Rating  Texture Rating  \
# 0     Mint Chocolate Chip     Vanilla   Yes           10.0             8.0
# 1               Chocolate   Chocolate   Yes            8.8             7.6
# 2                 Vanilla     Vanilla    No            4.7             5.0
# 3            Cookie Dough     Vanilla   Yes            6.9             6.5
# 4              Rocky Road   Chocolate   Yes            8.2             7.0
# 5               Pistachio     Vanilla    No            2.3             3.4
# 6             Cake Batter     Vanilla   Yes            6.5             6.0
# 7              Neapolitan     Vanilla    No            3.8             5.0
# 8  Chocolte Fudge Brownie   Chocolate   Yes            8.2             7.1
#
#    Total Rating
# 0          18.0
# 1          16.6
# 2           9.7
# 3          13.4
# 4          15.2
# 5           5.7
# 6          12.5
# 7           8.8
# 8          15.3

# %% [markdown]
# # Multiple grouping

# %%
dt.groupby(['Base Flavor','Liked']).sum()
# Out:
#                                                        Flavor  Flavor Rating  \
# Base Flavor Liked
# Chocolate   Yes     ChocolateRocky RoadChocolte Fudge Brownie           25.2
# Vanilla     No                     VanillaPistachioNeapolitan           10.8
#             Yes    Mint Chocolate ChipCookie DoughCake Batter           23.4
#
#                    Texture Rating  Total Rating
# Base Flavor Liked
# Chocolate   Yes              21.7          47.1
# Vanilla     No               13.4          24.2
#             Yes              20.5          43.9

# %%
dt.groupby(['Base Flavor','Liked']).agg({'Flavor Rating': ['max','count','sum','mean']})
# Out:
#                   Flavor Rating
#                             max count   sum mean
# Base Flavor Liked
# Chocolate   Yes             8.8     3  25.2  8.4
# Vanilla     No              4.7     3  10.8  3.6
#             Yes            10.0     3  23.4  7.8

# %%
dt.groupby('Base Flavor').describe()
# Out:
#             Flavor Rating                                             \
#                     count mean       std  min    25%  50%  75%   max
# Base Flavor
# Chocolate             3.0  8.4  0.346410  8.2  8.200  8.2  8.5   8.8
# Vanilla               6.0  5.7  2.710719  2.3  4.025  5.6  6.8  10.0
#
#             Texture Rating            ...             Total Rating         \
#                      count      mean  ...    75%  max        count   mean
# Base Flavor                           ...
# Chocolate              3.0  7.233333  ...  7.350  7.6          3.0  15.70
# Vanilla                6.0  5.650000  ...  6.375  8.0          6.0  11.35
#
#
#                   std   min     25%   50%     75%   max
# Base Flavor
# Chocolate    0.781025  15.2  15.250  15.3  15.950  16.6
# Vanilla      4.263684   5.7   9.025  11.1  13.175  18.0
#
# [2 rows x 24 columns]

# %% [markdown]
# # Merge, Join and Concatenate

# %%
df11 = pd.read_csv(r"C:\Users\Rishi\Downloads\LOTR.csv")

# %%
df11
# Out:
#    FellowshipID FirstName     Skills
# 0          1001     Frodo     Hiding
# 1          1002   Samwise  Gardening
# 2          1003   Gandalf     Spells
# 3          1004    Pippin  Fireworks

# %%
df22 = pd.read_csv(r"C:\Users\Rishi\Downloads\LOTR 2.csv")

# %%
df22
# Out:
#    FellowshipID FirstName   Age
# 0          1001     Frodo    50
# 1          1002   Samwise    39
# 2          1006   Legolas  2931
# 3          1007    Elrond  6520
# 4          1008  Barromir    51

# %% [markdown]
# # merge

# %%
# merge
df11.merge(df22)   # show inner join
# Out:
#    FellowshipID FirstName     Skills  Age
# 0          1001     Frodo     Hiding   50
# 1          1002   Samwise  Gardening   39

# %%
df11.merge(df22, how = 'inner', on = ['FellowshipID','FirstName'])   # show inner join
# Out:
#    FellowshipID FirstName     Skills  Age
# 0          1001     Frodo     Hiding   50
# 1          1002   Samwise  Gardening   39

# %%
df11.merge(df22, how = 'outer')
# Out:
#    FellowshipID FirstName     Skills     Age
# 0          1001     Frodo     Hiding    50.0
# 1          1002   Samwise  Gardening    39.0
# 2          1003   Gandalf     Spells     NaN
# 3          1004    Pippin  Fireworks     NaN
# 4          1006   Legolas        NaN  2931.0
# 5          1007    Elrond        NaN  6520.0
# 6          1008  Barromir        NaN    51.0

# %%
df11.merge(df22, how = 'left')
# Out:
#    FellowshipID FirstName     Skills   Age
# 0          1001     Frodo     Hiding  50.0
# 1          1002   Samwise  Gardening  39.0
# 2          1003   Gandalf     Spells   NaN
# 3          1004    Pippin  Fireworks   NaN

# %%
df11.merge(df22, how = 'right')
# Out:
#    FellowshipID FirstName     Skills   Age
# 0          1001     Frodo     Hiding    50
# 1          1002   Samwise  Gardening    39
# 2          1006   Legolas        NaN  2931
# 3          1007    Elrond        NaN  6520
# 4          1008  Barromir        NaN    51

# %% [markdown]
# # Cross join

# %%
df11.merge(df22, how = 'cross')
# Out:
#     FellowshipID_x FirstName_x     Skills  FellowshipID_y FirstName_y   Age
# 0             1001       Frodo     Hiding            1001       Frodo    50
# 1             1001       Frodo     Hiding            1002     Samwise    39
# 2             1001       Frodo     Hiding            1006     Legolas  2931
# 3             1001       Frodo     Hiding            1007      Elrond  6520
# 4             1001       Frodo     Hiding            1008    Barromir    51
# 5             1002     Samwise  Gardening            1001       Frodo    50
# 6             1002     Samwise  Gardening            1002     Samwise    39
# 7             1002     Samwise  Gardening            1006     Legolas  2931
# 8             1002     Samwise  Gardening            1007      Elrond  6520
# 9             1002     Samwise  Gardening            1008    Barromir    51
# 10            1003     Gandalf     Spells            1001       Frodo    50
# ...

# %% [markdown]
# # Joins

# %%
df11.join(df22, on= 'FellowshipID', how = 'outer', lsuffix = '_Left', rsuffix = '_Right')
# Out:
#      FellowshipID  FellowshipID_Left FirstName_Left     Skills  \
# 0.0          1001             1001.0          Frodo     Hiding
# 1.0          1002             1002.0        Samwise  Gardening
# 2.0          1003             1003.0        Gandalf     Spells
# 3.0          1004             1004.0         Pippin  Fireworks
# NaN             0                NaN            NaN        NaN
# NaN             1                NaN            NaN        NaN
# NaN             2                NaN            NaN        NaN
# NaN             3                NaN            NaN        NaN
# NaN             4                NaN            NaN        NaN
#
#      FellowshipID_Right FirstName_Right     Age
# 0.0                 NaN             NaN     NaN
# 1.0                 NaN             NaN     NaN
# 2.0                 NaN             NaN     NaN
# 3.0                 NaN             NaN     NaN
# NaN              1001.0           Frodo    50.0
# ...

# %%
df44 = df11.set_index('FellowshipID').join(df22.set_index('FellowshipID'), lsuffix = '_Left', rsuffix = '_Right', how = 'outer')
df44
# Out:
#              FirstName_Left     Skills FirstName_Right     Age
# FellowshipID
# 1001                  Frodo     Hiding           Frodo    50.0
# 1002                Samwise  Gardening         Samwise    39.0
# 1003                Gandalf     Spells             NaN     NaN
# 1004                 Pippin  Fireworks             NaN     NaN
# 1006                    NaN        NaN         Legolas  2931.0
# 1007                    NaN        NaN          Elrond  6520.0
# 1008                    NaN        NaN        Barromir    51.0

# %%
pd.concat([df11,df22])  # put dataframe 1 on top off df 2
# Out:
#    FellowshipID FirstName     Skills     Age
# 0          1001     Frodo     Hiding     NaN
# 1          1002   Samwise  Gardening     NaN
# 2          1003   Gandalf     Spells     NaN
# 3          1004    Pippin  Fireworks     NaN
# 0          1001     Frodo        NaN    50.0
# 1          1002   Samwise        NaN    39.0
# 2          1006   Legolas        NaN  2931.0
# 3          1007    Elrond        NaN  6520.0
# 4          1008  Barromir        NaN    51.0

# %%
pd.concat([df11,df22], join = 'inner')
# Out:
#    FellowshipID FirstName
# 0          1001     Frodo
# 1          1002   Samwise
# 2          1003   Gandalf
# 3          1004    Pippin
# 0          1001     Frodo
# 1          1002   Samwise
# 2          1006   Legolas
# 3          1007    Elrond
# 4          1008  Barromir

# %%
pd.concat([df11,df22], join = 'outer', axis = 1)
# Out:
#    FellowshipID FirstName     Skills  FellowshipID FirstName   Age
# 0        1001.0     Frodo     Hiding          1001     Frodo    50
# 1        1002.0   Samwise  Gardening          1002   Samwise    39
# 2        1003.0   Gandalf     Spells          1006   Legolas  2931
# 3        1004.0    Pippin  Fireworks          1007    Elrond  6520
# 4           NaN       NaN        NaN          1008  Barromir    51

# %% [markdown]
# #  Pandas Visualization

# %%
import pandas as pd
import numpy as np
import matplotlib as plt

# %%
pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
df = pd.read_csv(r"C:\Users\Rishi\Downloads\Ice Cream Ratings.csv")

# %%
df.reset_index(inplace=True)

# %%
df = df.set_index('Date')

# %%
df
# Out:
#           index  Flavor Rating  Texture Rating  Overall Rating
# Date
# 1/1/2022      0       0.223090        0.040220        0.600129
# 1/2/2022      1       0.635886        0.938476        0.106264
# 1/3/2022      2       0.442323        0.044154        0.598112
# 1/4/2022      3       0.389128        0.549676        0.489353
# 1/5/2022      4       0.386887        0.519439        0.988280
# 1/6/2022      5       0.877984        0.193588        0.832827
# 1/7/2022      6       0.140995        0.325110        0.105147

# %%
df.plot()  # default it will give as line plot
# Out:
# <Axes: xlabel='Date'>

# %%
df.plot(kind = 'line', title = 'Ice cream ratings', xlabel = 'Daily ratings', ylabel = 'Scores')
# Out:
# <Axes: title={'center': 'Ice cream ratings'}, xlabel='Daily ratings', ylabel='Scores'>

# %% [markdown]
# # Bar plot

# %%
df.plot(kind ='bar', stacked = True)
# Out:
# <Axes: xlabel='Date'>

# %%
df['Flavor Rating'].plot(kind ='bar', stacked = True)
# Out:
# <Axes: xlabel='Date'>

# %%
df.plot.barh(stacked = True)
# Out:
# <Axes: ylabel='Date'>

# %% [markdown]
# # Scatter plot

# %%
df.plot.scatter(x = 'Texture Rating', y = 'Overall Rating', s = 100, c = 'grey')
# Out:
# <Axes: xlabel='Texture Rating', ylabel='Overall Rating'>

# %% [markdown]
# # Histogram

# %%
df.plot.hist(bins = 10)
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# # Box plot

# %%
df.boxplot()
# Out:
# <Axes: >

# %%
 df.plot.area(figsize = (8,4))
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# # Pie chart

# %%
df.plot.pie(y='Flavor Rating', figsize = (10,6))
# Out:
# <Axes: ylabel='Flavor Rating'>

# %%
print(plt.style.available)
# Out:
# ['Solarize_Light2', '_classic_test_patch', '_mpl-gallery', '_mpl-gallery-nogrid', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn-v0_8', 'seaborn-v0_8-bright', 'seaborn-v0_8-colorblind', 'seaborn-v0_8-dark', 'seaborn-v0_8-dark-palette', 'seaborn-v0_8-darkgrid', 'seaborn-v0_8-deep', 'seaborn-v0_8-muted', 'seaborn-v0_8-notebook', 'seaborn-v0_8-paper', 'seaborn-v0_8-pastel', 'seaborn-v0_8-poster', 'seaborn-v0_8-talk', 'seaborn-v0_8-ticks', 'seaborn-v0_8-white', 'seaborn-v0_8-whitegrid', 'tableau-colorblind10']

# %% [markdown]
# #  Data Cleaning in Pandas

# %%
import pandas as pd

# %%
df = pd.read_excel(r"C:\Users\Rishi\Downloads\Customer Call List.xlsx")

# %%
df
# Out:
#     CustomerID First_Name    Last_Name  Phone_Number  \
# 0         1001      Frodo      Baggins  123-545-5421
# 1         1002       Abed        Nadir  123/643/9775
# 2         1003     Walter       /White    7066950392
# 3         1004     Dwight      Schrute  123-543-2345
# 4         1005        Jon         Snow  876|678|3469
# 5         1006        Ron      Swanson  304-762-2467
# 6         1007       Jeff       Winger           NaN
# 7         1008   Sherlock       Holmes  876|678|3469
# 8         1009    Gandalf          NaN           N/a
# 9         1010      Peter       Parker  123-545-5421
# 10        1011    Samwise       Gamgee           NaN
# 11        1012      Harry    ...Potter    7066950392
# 12        1013        Don       Draper  123-543-2345
# 13        1014     Leslie        Knope  876|678|3469
# 14        1015       Toby  Flenderson_  304-762-2467
# 15        1016        Ron      Weasley  123-545-5421
# 16        1017   Michael         Scott  123/643/9775
# ...

# %%
df = df.drop_duplicates()
df
# Out:
#     CustomerID First_Name    Last_Name  Phone_Number  \
# 0         1001      Frodo      Baggins  123-545-5421
# 1         1002       Abed        Nadir  123/643/9775
# 2         1003     Walter       /White    7066950392
# 3         1004     Dwight      Schrute  123-543-2345
# 4         1005        Jon         Snow  876|678|3469
# 5         1006        Ron      Swanson  304-762-2467
# 6         1007       Jeff       Winger           NaN
# 7         1008   Sherlock       Holmes  876|678|3469
# 8         1009    Gandalf          NaN           N/a
# 9         1010      Peter       Parker  123-545-5421
# 10        1011    Samwise       Gamgee           NaN
# 11        1012      Harry    ...Potter    7066950392
# 12        1013        Don       Draper  123-543-2345
# 13        1014     Leslie        Knope  876|678|3469
# 14        1015       Toby  Flenderson_  304-762-2467
# 15        1016        Ron      Weasley  123-545-5421
# 16        1017   Michael         Scott  123/643/9775
# ...

# %%
# df = df.drop(columns = 'Not_Useful_Column')  # or you can say inplace = true,,,, to save it
# execute
df.head(2)
# Out:
#    CustomerID First_Name Last_Name  Phone_Number                Address  \
# 0        1001      Frodo   Baggins  123-545-5421  123 Shire Lane, Shire
# 1        1002       Abed     Nadir  123/643/9775    93 West Main Street
#
#   Paying Customer Do_Not_Contact  Not_Useful_Column
# 0             Yes             No               True
# 1              No            Yes              False

# %%
df["Last_Name"].str.lstrip(["...","/"]) # not working on multiple
# Out:
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN
# 5    NaN
# 6    NaN
# 7    NaN
# 8    NaN
# 9    NaN
# 10   NaN
# 11   NaN
# 12   NaN
# 13   NaN
# 14   NaN
# 15   NaN
# 16   NaN
# 17   NaN
# 18   NaN
# 19   NaN
# Name: Last_Name, dtype: float64

# %%
df["Last_Name"] = df["Last_Name"].str.lstrip("...")
df["Last_Name"] = df["Last_Name"].str.lstrip("/")
df["Last_Name"] = df["Last_Name"].str.rstrip("_")
df
# Out:
# C:\Users\Rishi\AppData\Local\Temp\ipykernel_5632\4255608063.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Last_Name"] = df["Last_Name"].str.lstrip("...")
# C:\Users\Rishi\AppData\Local\Temp\ipykernel_5632\4255608063.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Last_Name"] = df["Last_Name"].str.lstrip("/")
# C:\Users\Rishi\AppData\Local\Temp\ipykernel_5632\4255608063.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %% [markdown]
# Another way

# %%
# df["Last_Name"].str.strip("123./")  {it will remove all in once  }

# %%
df
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number  \
# 0         1001      Frodo     Baggins  123-545-5421
# 1         1002       Abed       Nadir  123/643/9775
# 2         1003     Walter       White    7066950392
# 3         1004     Dwight     Schrute  123-543-2345
# 4         1005        Jon        Snow  876|678|3469
# 5         1006        Ron     Swanson  304-762-2467
# 6         1007       Jeff      Winger           NaN
# 7         1008   Sherlock      Holmes  876|678|3469
# 8         1009    Gandalf         NaN           N/a
# 9         1010      Peter      Parker  123-545-5421
# 10        1011    Samwise      Gamgee           NaN
# 11        1012      Harry      Potter    7066950392
# 12        1013        Don      Draper  123-543-2345
# 13        1014     Leslie       Knope  876|678|3469
# 14        1015       Toby  Flenderson  304-762-2467
# 15        1016        Ron     Weasley  123-545-5421
# 16        1017   Michael        Scott  123/643/9775
# ...

# %% [markdown]
# Clean Phone number

# %%
df["Phone_Number"].str.replace('[^a-zA-Z0-9]','')       # not working
#df["Phone_Number"].apply(lambda x: x[0:3] + '-' + x[3:6] + '-' + x[6:10])


#df["Phone_Number"] = df["Phone_Number"].apply(lambda x: x[0:3] + '-' + x[3:6] + '-' + x[6:10])

# df["Phone_Number"] = df["Phone_Number"].str.replace('nan--','')

# df["Phone_Number"] = df["Phone_Number"].str.replace('Na--','')
# # df
# Out:
# 0     123-545-5421
# 1     123/643/9775
# 2              NaN
# 3     123-543-2345
# 4     876|678|3469
# 5     304-762-2467
# 6              NaN
# 7     876|678|3469
# 8              N/a
# 9     123-545-5421
# 10             NaN
# 11             NaN
# 12    123-543-2345
# 13    876|678|3469
# 14    304-762-2467
# 15    123-545-5421
# 16    123/643/9775
# 17             NaN
# 18             N/a
# 19    876|678|3469
# Name: Phone_Number, dtype: object

# %%
df
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number  \
# 0         1001      Frodo     Baggins  123-545-5421
# 1         1002       Abed       Nadir  123/643/9775
# 2         1003     Walter       White    7066950392
# 3         1004     Dwight     Schrute  123-543-2345
# 4         1005        Jon        Snow  876|678|3469
# 5         1006        Ron     Swanson  304-762-2467
# 6         1007       Jeff      Winger           NaN
# 7         1008   Sherlock      Holmes  876|678|3469
# 8         1009    Gandalf         NaN           N/a
# 9         1010      Peter      Parker  123-545-5421
# 10        1011    Samwise      Gamgee           NaN
# 11        1012      Harry      Potter    7066950392
# 12        1013        Don      Draper  123-543-2345
# 13        1014     Leslie       Knope  876|678|3469
# 14        1015       Toby  Flenderson  304-762-2467
# 15        1016        Ron     Weasley  123-545-5421
# 16        1017   Michael        Scott  123/643/9775
# ...

# %%
# df[["Street_Address", "State", "Zip_Code"]] = df["Address"].str.split(',',2, expand=True)
# df                                Not working

# %%
df["Do_Not_Contact"] = df["Do_Not_Contact"].str.replace('Yes','Y')

df["Do_Not_Contact"] = df["Do_Not_Contact"].str.replace('No','N')
df                      # not workingggg
# Out:
# C:\Users\Rishi\AppData\Local\Temp\ipykernel_5632\3936254620.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Do_Not_Contact"] = df["Do_Not_Contact"].str.replace('Yes','Y')
# C:\Users\Rishi\AppData\Local\Temp\ipykernel_5632\3936254620.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Do_Not_Contact"] = df["Do_Not_Contact"].str.replace('No','N')
#     CustomerID First_Name   Last_Name  Phone_Number  \
# 0         1001      Frodo     Baggins  123-545-5421
# ...

# %%
#df = df.replace('N/a','')
#df = df.replace('NaN','')


df=df.fillna('')
df
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number  \
# 0         1001      Frodo     Baggins  123-545-5421
# 1         1002       Abed       Nadir  123/643/9775
# 2         1003     Walter       White    7066950392
# 3         1004     Dwight     Schrute  123-543-2345
# 4         1005        Jon        Snow  876|678|3469
# 5         1006        Ron     Swanson  304-762-2467
# 6         1007       Jeff      Winger
# 7         1008   Sherlock      Holmes  876|678|3469
# 8         1009    Gandalf                       N/a
# 9         1010      Peter      Parker  123-545-5421
# 10        1011    Samwise      Gamgee
# 11        1012      Harry      Potter    7066950392
# 12        1013        Don      Draper  123-543-2345
# 13        1014     Leslie       Knope  876|678|3469
# 14        1015       Toby  Flenderson  304-762-2467
# 15        1016        Ron     Weasley  123-545-5421
# 16        1017   Michael        Scott  123/643/9775
# ...

# %% [markdown]
# # Exploratory Data Analysis

# %%
import pandas as pd
import seaborn as sns
import matplotlib as plt

# %%
dff =  pd.read_csv(r"C:\Users\Rishi\Downloads\world_population.csv")
dff
# Out:
#      Rank CCA3            Country           Capital Continent  \
# 0      36  AFG        Afghanistan             Kabul      Asia
# 1     138  ALB            Albania            Tirana    Europe
# 2      34  DZA            Algeria           Algiers    Africa
# 3     213  ASM     American Samoa         Pago Pago   Oceania
# 4     203  AND            Andorra  Andorra la Vella    Europe
# ..    ...  ...                ...               ...       ...
# 229   226  WLF  Wallis and Futuna          Mata-Utu   Oceania
# 230   172  ESH     Western Sahara          El Aaiún    Africa
# 231    46  YEM              Yemen             Sanaa      Asia
# 232    63  ZMB             Zambia            Lusaka    Africa
# 233    74  ZWE           Zimbabwe            Harare    Africa
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 0         41128771.0       38972230.0       33753499.0       28189672.0
# 1          2842321.0        2866849.0        2882481.0        2913399.0
# ...

# %%
pd.set_option('display.float_format', lambda x: '%.2f' % x)

# %%
dff.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 234 entries, 0 to 233
# Data columns (total 17 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Rank                         234 non-null    int64
#  1   CCA3                         234 non-null    object
#  2   Country                      234 non-null    object
#  3   Capital                      234 non-null    object
#  4   Continent                    234 non-null    object
#  5   2022 Population              230 non-null    float64
#  6   2020 Population              233 non-null    float64
#  7   2015 Population              230 non-null    float64
#  8   2010 Population              227 non-null    float64
#  9   2000 Population              227 non-null    float64
#  10  1990 Population              229 non-null    float64
#  11  1980 Population              229 non-null    float64
# ...

# %%
dff.describe()
# Out:
#         Rank  2022 Population  2020 Population  2015 Population  \
# count 234.00           230.00           233.00           230.00
# mean  117.50      34632250.88      33600710.95      32066004.16
# std    67.69     137889172.44     135873196.61     131507146.34
# min     1.00           510.00           520.00           564.00
# 25%    59.25        419738.50        406471.00        394295.00
# 50%   117.50       5762857.00       5456681.00       5244415.00
# 75%   175.75      22653719.00      21522626.00      19730853.75
# max   234.00    1425887337.00    1424929781.00    1393715448.00
#
#        2010 Population  2000 Population  1990 Population  1980 Population  \
# count           227.00           227.00           229.00           229.00
# mean       30270164.48      26840495.26      19330463.93      16282884.78
# std       126074183.54     113352454.57      81309624.96      69345465.54
# min             596.00           651.00           700.00           733.00
# ...

# %%
dff.isnull().sum()
# Out:
# Rank                           0
# CCA3                           0
# Country                        0
# Capital                        0
# Continent                      0
# 2022 Population                4
# 2020 Population                1
# 2015 Population                4
# 2010 Population                7
# 2000 Population                7
# 1990 Population                5
# 1980 Population                5
# 1970 Population                4
# Area (km²)                     2
# Density (per km²)              4
# Growth Rate                    2
# World Population Percentage    0
# dtype: int64

# %%
dff.nunique()
# Out:
# Rank                           234
# CCA3                           234
# Country                        234
# Capital                        234
# Continent                        6
# 2022 Population                230
# 2020 Population                233
# 2015 Population                230
# 2010 Population                227
# 2000 Population                227
# 1990 Population                229
# 1980 Population                229
# 1970 Population                230
# Area (km²)                     231
# Density (per km²)              230
# Growth Rate                    178
# World Population Percentage     70
# dtype: int64

# %%
dff.sort_values(by="2022 Population", ascending=False).head(9)
# Out:
#      Rank CCA3        Country           Capital      Continent  \
# 41      1  CHN          China           Beijing           Asia
# 92      2  IND          India         New Delhi           Asia
# 221     3  USA  United States  Washington, D.C.  North America
# 93      4  IDN      Indonesia           Jakarta           Asia
# 156     5  PAK       Pakistan         Islamabad           Asia
# 149     6  NGA        Nigeria             Abuja         Africa
# 27      7  BRA         Brazil          Brasilia  South America
# 16      8  BGD     Bangladesh             Dhaka           Asia
# 171     9  RUS         Russia            Moscow         Europe
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 41     1425887337.00    1424929781.00    1393715448.00    1348191368.00
# 92     1417173173.00    1396387127.00    1322866505.00    1240613620.00
# 221     338289857.00     335942003.00     324607776.00     311182845.00
# ...

# %%
dff.sort_values(by="World Population Percentage", ascending=False).head(6)
# Out:
#      Rank CCA3        Country           Capital      Continent  \
# 41      1  CHN          China           Beijing           Asia
# 92      2  IND          India         New Delhi           Asia
# 221     3  USA  United States  Washington, D.C.  North America
# 93      4  IDN      Indonesia           Jakarta           Asia
# 156     5  PAK       Pakistan         Islamabad           Asia
# 149     6  NGA        Nigeria             Abuja         Africa
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 41     1425887337.00    1424929781.00    1393715448.00    1348191368.00
# 92     1417173173.00    1396387127.00    1322866505.00    1240613620.00
# 221     338289857.00     335942003.00     324607776.00     311182845.00
# 93      275501339.00     271857970.00     259091970.00     244016173.00
# 156     235824862.00     227196741.00     210969298.00     194454498.00
# 149     218541212.00     208327405.00     183995785.00     160952853.00
#
# ...

# %%
# dff.corr()  # showing error

# %%
# sns.heatmap(dff.corr(), annot = True)
# plt.rcParams['Figure.figsize'] = (20,10)
# plt.show()



# could not convert string to float: 'AFG'

# %%
dff.groupby('Continent').count().sort_values(by = "2022 Population", ascending=False)
#dff.groupby('Continent').mean()       # not working
# Out:
#                Rank  CCA3  Country  Capital  2022 Population  2020 Population  \
# Continent
# Africa           57    57       57       57               56               57
# Asia             50    50       50       50               49               49
# Europe           50    50       50       50               49               50
# North America    40    40       40       40               40               40
# Oceania          23    23       23       23               22               23
# South America    14    14       14       14               14               14
#
#                2015 Population  2010 Population  2000 Population  \
# Continent
# Africa                      54               54               56
# Asia                        50               47               46
# Europe                      49               50               49
# North America               40               40               40
# Oceania                     23               23               23
# ...

# %%
dff[dff['Continent'].str.contains('Oceania')]
# Out:
#      Rank CCA3                   Country       Capital Continent  \
# 3     213  ASM            American Samoa     Pago Pago   Oceania
# 11     55  AUS                 Australia      Canberra   Oceania
# 44    223  COK              Cook Islands        Avarua   Oceania
# 66    162  FJI                      Fiji          Suva   Oceania
# 70    183  PYF          French Polynesia       Papeete   Oceania
# 81    191  GUM                      Guam       Hagåtña   Oceania
# 107   192  KIR                  Kiribati        Tarawa   Oceania
# 126   215  MHL          Marshall Islands        Majuro   Oceania
# 132   194  FSM                Micronesia       Palikir   Oceania
# 142   225  NRU                     Nauru         Yaren   Oceania
# 145   185  NCL             New Caledonia        Nouméa   Oceania
# 146   123  NZL               New Zealand    Wellington   Oceania
# 150   232  NIU                      Niue         Alofi   Oceania
# ...

# %%
# df2 = dff.groupby('Continent')[df.columns[5:13]].count().sort_values(by = "2022 Population", ascending=False)

df2 = dff.groupby('Continent')[['1970 Population',
       '1980 Population', '1990 Population', '2000 Population',
       '2010 Population', '2015 Population', '2020 Population',
       '2022 Population']].count().sort_values(by = "2022 Population", ascending=False)
df2
# Out:
#                1970 Population  1980 Population  1990 Population  \
# Continent
# Africa                      55               56               56
# Asia                        48               48               48
# Europe                      50               48               48
# North America               40               40               40
# Oceania                     23               23               23
# South America               14               14               14
#
#                2000 Population  2010 Population  2015 Population  \
# Continent
# Africa                      56               54               54
# Asia                        46               47               50
# Europe                      49               50               49
# North America               40               40               40
# Oceania                     23               23               23
# South America               13               13               14
#
# ...

# %%
dff.columns
# Out:
# Index(['Rank', 'CCA3', 'Country', 'Capital', 'Continent', '2022 Population',
#        '2020 Population', '2015 Population', '2010 Population',
#        '2000 Population', '1990 Population', '1980 Population',
#        '1970 Population', 'Area (km²)', 'Density (per km²)', 'Growth Rate',
#        'World Population Percentage'],
#       dtype='object')

# %%
df3 = df2.transpose()
df3
# Out:
# Continent        Africa  Asia  Europe  North America  Oceania  South America
# 1970 Population      55    48      50             40       23             14
# 1980 Population      56    48      48             40       23             14
# 1990 Population      56    48      48             40       23             14
# 2000 Population      56    46      49             40       23             13
# 2010 Population      54    47      50             40       23             13
# 2015 Population      54    50      49             40       23             14
# 2020 Population      57    49      50             40       23             14
# 2022 Population      56    49      49             40       22             14

# %%
df3.plot(figsize=(20,10))
# Out:
# <Axes: >

# %%
df3.boxplot(figsize=(20,10))
# Out:
# <Axes: >

# %%
dff.select_dtypes(include='number')  # this will show only....numeric value
# Out:
#      Rank  2022 Population  2020 Population  2015 Population  2010 Population  \
# 0      36      41128771.00      38972230.00      33753499.00      28189672.00
# 1     138       2842321.00       2866849.00       2882481.00       2913399.00
# 2      34      44903225.00      43451666.00      39543154.00      35856344.00
# 3     213         44273.00         46189.00         51368.00         54849.00
# 4     203         79824.00         77700.00         71746.00         71519.00
# ..    ...              ...              ...              ...              ...
# 229   226         11572.00         11655.00         12182.00         13142.00
# 230   172        575986.00        556048.00        491824.00        413296.00
# 231    46      33696614.00      32284046.00      28516545.00      24743946.00
# 232    63      20017675.00      18927715.00              NaN      13792086.00
# 233    74      16320537.00      15669666.00      14154937.00      12839771.00
#
# ...

# %%
dff.select_dtypes(include='object')
# Out:
#     CCA3            Country           Capital Continent
# 0    AFG        Afghanistan             Kabul      Asia
# 1    ALB            Albania            Tirana    Europe
# 2    DZA            Algeria           Algiers    Africa
# 3    ASM     American Samoa         Pago Pago   Oceania
# 4    AND            Andorra  Andorra la Vella    Europe
# ..   ...                ...               ...       ...
# 229  WLF  Wallis and Futuna          Mata-Utu   Oceania
# 230  ESH     Western Sahara          El Aaiún    Africa
# 231  YEM              Yemen             Sanaa      Asia
# 232  ZMB             Zambia            Lusaka    Africa
# 233  ZWE           Zimbabwe            Harare    Africa
#
# [234 rows x 4 columns]

# %% [markdown]
# # Assignment 1 – Pandas

# %% [markdown]
# 1. Start off by importing the customer_churn.csv file in the jupyter notebook and store that in churn DataFrame.

# %%
import pandas as pd

churn_df = pd.read_csv(r"C:\Users\Rishi\Downloads\customer_churn.csv")
churn_df
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# ...

# %% [markdown]
# 2. From the churn DataFrame, select only 3rd, 7th, 9th, and 20th columns and all the rows and store that in a new DataFrame named newCols.

# %%
newCols = churn_df.iloc[:, [2, 6, 8, 19]]
newCols
# Out:
#       SeniorCitizen PhoneService InternetService TotalCharges
# 0                 0           No             DSL        29.85
# 1                 0          Yes             DSL       1889.5
# 2                 0          Yes             DSL       108.15
# 3                 0           No             DSL      1840.75
# 4                 0          Yes     Fiber optic       151.65
# ...             ...          ...             ...          ...
# 7038              0          Yes             DSL       1990.5
# 7039              0          Yes     Fiber optic       7362.9
# 7040              0           No             DSL       346.45
# 7041              1          Yes     Fiber optic        306.6
# 7042              0          Yes     Fiber optic       6844.5
#
# [7043 rows x 4 columns]

# %% [markdown]
# 3. From the original DataFrame, select only the rows from the 200th index till the 1000th index(inclusive) column.

# %%
selected_rows = churn_df[200:1001]
  # Inclusive of both 200 and 1000
selected_rows
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 200   9323-HGFWY  Female              0     Yes         No      27
# 201   8544-GOQSH  Female              0      No         No      14
# 202   3363-DTIVD    Male              0     Yes        Yes      71
# 203   7018-WBJNK    Male              0      No        Yes      13
# 204   9142-KZXOP    Male              0      No         No      44
# ...          ...     ...            ...     ...        ...     ...
# 996   6641-XRPSU  Female              0      No         No      34
# 997   1374-DMZUI  Female              1      No         No       4
# 998   2545-LXYVJ    Male              0     Yes         No      72
# 999   3234-VKACU    Male              0      No         No       2
# 1000  8357-EQXFO  Female              0      No         No       7
#
#      PhoneService MultipleLines InternetService       OnlineSecurity  ...  \
# 200           Yes            No     Fiber optic                  Yes  ...
# ...

# %% [markdown]
# 4. Now select the rows from 20th index till 200th index(exclusive),and columns from 2nd index till 15th index value.

# %%
select_rows = churn_df.iloc[20:200, 2:15]
select_rows
# Out:
#      SeniorCitizen Partner Dependents  tenure PhoneService     MultipleLines  \
# 20               1      No         No       1           No  No phone service
# 21               0     Yes         No      12          Yes                No
# 22               0      No         No       1          Yes                No
# 23               0     Yes         No      58          Yes               Yes
# 24               0     Yes        Yes      49          Yes                No
# ..             ...     ...        ...     ...          ...               ...
# 195              0     Yes         No      20          Yes                No
# 196              0     Yes        Yes      24          Yes               Yes
# 197              0      No         No      59          Yes               Yes
# 198              0     Yes        Yes      72          Yes               Yes
# 199              0      No        Yes       1          Yes                No
#
# ...

# %% [markdown]
# 5. Display the top 100 records from the original DataFrame.

# %%
top_100_rec = churn_df.head(100)
top_100_rec
# Out:
#     customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0   7590-VHVEG  Female              0     Yes         No       1           No
# 1   5575-GNVDE    Male              0      No         No      34          Yes
# 2   3668-QPYBK    Male              0      No         No       2          Yes
# 3   7795-CFOCW    Male              0      No         No      45           No
# 4   9237-HQITU  Female              0      No         No       2          Yes
# ..         ...     ...            ...     ...        ...     ...          ...
# 95  8637-XJIVR  Female              0      No         No      12          Yes
# 96  9803-FTJCG    Male              0     Yes        Yes      71          Yes
# 97  0278-YXOOG    Male              0      No         No       5          Yes
# 98  3212-KXOCR    Male              0      No         No      52          Yes
# 99  4598-XLKNJ  Female              1     Yes         No      25          Yes
#
# ...

# %% [markdown]
# 6. Display the last 10 records from the DataFrame.
#
# 7. Display the last record from the DataFrame.

# %%
last_10_rec = churn_df.tail(10)
last_10_rec
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 7033  9767-FFLEM    Male              0      No         No      38
# 7034  0639-TSIQW  Female              0      No         No      67
# 7035  8456-QDAVC    Male              0      No         No      19
# 7036  7750-EYXWZ  Female              0      No         No      12
# 7037  2569-WGERO  Female              0      No         No      72
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService       OnlineSecurity  ...  \
# 7033          Yes                No     Fiber optic                   No  ...
# ...

# %%
#   8 
churn_df.tail(1)
# Out:
#       customerID gender  SeniorCitizen Partner Dependents  tenure  \
# 7042  3186-AJIEK   Male              0      No         No      66
#
#      PhoneService MultipleLines InternetService OnlineSecurity  ...  \
# 7042          Yes            No     Fiber optic            Yes  ...
#
#      DeviceProtection TechSupport StreamingTV StreamingMovies  Contract  \
# 7042              Yes         Yes         Yes             Yes  Two year
#
#      PaperlessBilling              PaymentMethod MonthlyCharges  TotalCharges  \
# 7042              Yes  Bank transfer (automatic)         105.65        6844.5
#
#      Churn
# 7042    No
#
# [1 rows x 21 columns]

# %% [markdown]
# 8. Now from the churn DataFrame, try to sort the data by the tenure column according to the descending order.

# %%
churn_df.sort_values(by='tenure', ascending=False)
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 1672  4737-AQCPU    Male              0     Yes        Yes      72
# 193   9680-NIAUV  Female              0     Yes        Yes      72
# 4553  5914-XRFQB    Male              0     Yes         No      72
# 483   5168-MQQCA  Female              0     Yes         No      72
# 3266  0464-WJTKO  Female              0     Yes        Yes      72
# ...          ...     ...            ...     ...        ...     ...
# 1082  4367-NUYAO    Male              0     Yes        Yes       0
# 3826  3213-VVOLG    Male              0     Yes        Yes       0
# 936   5709-LVOEQ  Female              0     Yes        Yes       0
# 6754  2775-SEFEE    Male              0      No        Yes       0
# 1340  1371-DWPAZ  Female              0     Yes        Yes       0
#
#      PhoneService     MultipleLines InternetService       OnlineSecurity  ...  \
# 1672          Yes               Yes             DSL                  Yes  ...
# ...

# %% [markdown]
# 9. Fetch all the records that are satisfying the following condition:
#
# a. Tenure>50 and the gender as ‘Female’
#
# b. Gender as ‘Male’ and SeniorCitizen as 0
#
# c. TechSupport as ‘Yes’ and Churn as ‘No’
#
# d. Contract type as ‘Month-to-month’ and Churn as ‘Yes’

# %%
a = churn_df[(churn_df['tenure'] > 50) & (churn_df['gender'] == 'Female')]
a
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 15    3655-SNQYZ  Female              0     Yes        Yes      69
# 16    8191-XWSZG  Female              0      No         No      52
# 23    3638-WEABW  Female              0     Yes         No      58
# 30    3841-NFECX  Female              1     Yes         No      71
# 35    6234-RAAPL  Female              0     Yes        Yes      72
# ...          ...     ...            ...     ...        ...     ...
# 7023  1035-IPQPU  Female              1     Yes         No      63
# 7028  9281-CEDRU  Female              0     Yes         No      68
# 7034  0639-TSIQW  Female              0      No         No      67
# 7037  2569-WGERO  Female              0      No         No      72
# 7039  2234-XADUH  Female              0     Yes        Yes      72
#
#      PhoneService MultipleLines InternetService       OnlineSecurity  ...  \
# 15            Yes           Yes     Fiber optic                  Yes  ...
# ...

# %%
b = churn_df[(churn_df['gender'] == 'Male') & (churn_df['SeniorCitizen'] == 0)]
b
# Out:
#       customerID gender  SeniorCitizen Partner Dependents  tenure  \
# 1     5575-GNVDE   Male              0      No         No      34
# 2     3668-QPYBK   Male              0      No         No       2
# 3     7795-CFOCW   Male              0      No         No      45
# 6     1452-KIOVK   Male              0      No        Yes      22
# 9     6388-TABGU   Male              0      No        Yes      62
# ...          ...    ...            ...     ...        ...     ...
# 7027  0550-DCXLH   Male              0      No         No      13
# 7033  9767-FFLEM   Male              0      No         No      38
# 7035  8456-QDAVC   Male              0      No         No      19
# 7038  6840-RESVB   Male              0     Yes        Yes      24
# 7042  3186-AJIEK   Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 1             Yes                No             DSL            Yes  ...
# ...

# %%
c = churn_df[(churn_df['TechSupport'] == 'Yes') & (churn_df['Churn']=='No')]
c
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 3     7795-CFOCW    Male              0      No         No      45
# 14    5129-JLPIS    Male              0      No         No      25
# 15    3655-SNQYZ  Female              0     Yes        Yes      69
# 23    3638-WEABW  Female              0     Yes         No      58
# 24    6322-HRPFA    Male              0     Yes        Yes      49
# ...          ...     ...            ...     ...        ...     ...
# 7027  0550-DCXLH    Male              0      No         No      13
# 7028  9281-CEDRU  Female              0     Yes         No      68
# 7036  7750-EYXWZ  Female              0      No         No      12
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 3              No  No phone service             DSL            Yes  ...
# ...

# %%
d = churn_df[(churn_df['Contract'] == 'Month-to-month') & (churn_df['Churn'] == 'Yes')]
d
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 2     3668-QPYBK    Male              0      No         No       2
# 4     9237-HQITU  Female              0      No         No       2
# 5     9305-CDSKC  Female              0      No         No       8
# 8     7892-POOKP  Female              0     Yes         No      28
# 13    0280-XJGEX    Male              0      No         No      49
# ...          ...     ...            ...     ...        ...     ...
# 7018  1122-JWTJW    Male              0     Yes        Yes       1
# 7026  8775-CEBBJ  Female              0      No         No       9
# 7032  6894-LFHLY    Male              1      No         No       1
# 7034  0639-TSIQW  Female              0      No         No      67
# 7041  8361-LTMKD    Male              1     Yes         No       4
#
#      PhoneService MultipleLines InternetService OnlineSecurity  ...  \
# 2             Yes            No             DSL            Yes  ...
# ...

# %% [markdown]
# 10. Use a for loop to calculate the number of customers that are getting the tech support and are male senior citizens

# %%
count = 0
for index, row in churn_df.iterrows():
    if row['TechSupport'] == 'Yes' and row['gender'] == 'Male' and row['SeniorCitizen'] == 1:
        count += 1

# %%
print(count)
# Out:
# 119

# %% [markdown]
# # Assignment 2 – Pandas

# %% [markdown]
# 1. Now select the rows from 20th index till 200th index (exclusive) and columns from 2nd index till 15th index value.

# %%
x = churn_df.iloc[20:200, 2:15]
x
# Out:
#      SeniorCitizen Partner Dependents  tenure PhoneService     MultipleLines  \
# 20               1      No         No       1           No  No phone service
# 21               0     Yes         No      12          Yes                No
# 22               0      No         No       1          Yes                No
# 23               0     Yes         No      58          Yes               Yes
# 24               0     Yes        Yes      49          Yes                No
# ..             ...     ...        ...     ...          ...               ...
# 195              0     Yes         No      20          Yes                No
# 196              0     Yes        Yes      24          Yes               Yes
# 197              0      No         No      59          Yes               Yes
# 198              0     Yes        Yes      72          Yes               Yes
# 199              0      No        Yes       1          Yes                No
#
# ...

# %% [markdown]
# # Case Study Problem 1

# %%
# 1. Write a function that takes start and end of a range returns a pandas series object containing numbers within that range.
# In case the user does not pass start or end or both they should default to 1 and 10 respectively. E.g:
# -> range_series() -> Should Return a pandas series from 1 to 10
# range_series(5) -> Should Return a pandas series from 5 to 10
# range_series(5, 10) -> Should Return a pandas series from 5 to 15
# Create a method that takes n NumPy arrays of the same dimensions,
# sums them and returns the answer.

# %%
def range_s(start=1, end=10):
    return pd.Series(range(start, end + 1))

# %%
print(range_s(5))
# Out:
# 0     5
# 1     6
# 2     7
# 3     8
# 4     9
# 5    10
# dtype: int64

# %%
print(range_s(5, 15))
# Out:
# 0      5
# 1      6
# 2      7
# 3      8
# 4      9
# 5     10
# 6     11
# 7     12
# 8     13
# 9     14
# 10    15
# dtype: int64

# %%
import numpy as np

# %%
# 2. Create a function that takes in two lists named keys and values as arguments
# Keys would be strings and contain n string values
# Values would be a list containing n lists
# The methods should return a new pandas DataFrame with keys as column
# names and values as their corresponding values, e.g:
# ->create_dataframe(["One", "Two"], [["X", "Y"], ["A", "B"]]) -> should return a
# data frame
# One Two
# 0 X A
# 1 Y B

# %%
def sum_arrays(*arrays):
    return np.sum(arrays, axis=0)

# %%
array1 = np.array([1, 2, 3])
array2 = np.array([4, 5, 6])
array3 = np.array([7, 8, 9])
print(sum_arrays(array1, array2, array3))
# Out:
# [12 15 18]

# %% [markdown]
# 3. Create a function that concatenates two DataFrames. Use a previously
# created function to create two DataFrames and pass them as parameters
# Make sure that the indexes are reset before returning.

# %%
def create_dataframe(keys, values):
    data = dict(zip(keys, zip(*values)))
    return pd.DataFrame(data)

# %%
keys = ["One", "Two"]
values = [["X", "Y"], ["A", "B"]]
print(create_dataframe(keys, values))
# Out:
#   One Two
# 0   X   Y
# 1   A   B
