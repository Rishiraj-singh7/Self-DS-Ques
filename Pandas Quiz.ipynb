# %% [markdown]
# Description of the Dataset:
# This dataset contains these columns:
# id, date, price, bedrooms, bathrooms, sqft_living, sqft_lot, floors, waterfront, view, condition, grade,
# sqft_above, sqft_basement, yr_built, yr_renovated, zip code, lat, long, sqft_living15, sqft_lot15.

# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\Rishi\Downloads\housing.csv")

# %%
df
# Out:
#                id             date   price  bedrooms  bathrooms  sqft_living  \
# 0      7129300520  20141013T000000  221900         3       1.00         1180
# 1      6414100192  20141209T000000  538000         3       2.25         2570
# 2      5631500400  20150225T000000  180000         2       1.00          770
# 3      2487200875  20141209T000000  604000         4       3.00         1960
# 4      1954400510  20150218T000000  510000         3       2.00         1680
# ...           ...              ...     ...       ...        ...          ...
# 21608   263000018  20140521T000000  360000         3       2.50         1530
# 21609  6600060120  20150223T000000  400000         4       2.50         2310
# 21610  1523300141  20140623T000000  402101         2       0.75         1020
# 21611   291310100  20150116T000000  400000         3       2.50         1600
# 21612  1523300157  20141015T000000  325000         2       0.75         1020
#
# ...

# %%
df.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
# 1. How many houses have a waterfront?
# A. 140 B. 340 C. 323 D. 163

df['waterfront'].sum()
# Out:
# 163

# %%
# 2. Which zip code has the costliest house? 
# A. 98456 B. 98102 C. 98283 D. 89034

df.loc[df['price'].idxmax()]['zipcode']
# Out:
# 98102

# %%
# 3. How many houses are having grade 10?
# A. 1133 B. 1134 C. 1135 D. 1132 

df[df['grade'] == 10].shape[0]
# Out:
# 1134

# %%
# 4. How many null values are there in the dataset? 
# A. 20 B. 19 C. 0 D. 4 

df.isnull().sum()
# Out:
# id               0
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# 0

# %%
# 5. Does this 9126100861 customer have a waterfront? A. Yes B. No 

df_wf = 'Yes' if df[df['id'] == 9126100861]['waterfront'].values[0] == 1 else 'No'
df_wf
# Out:
# 'No'

# %%
# 6. How many houses have 3 views? 
# A. 340 B. 550 C. 510 D. 90 

df[df['view'] == 3].shape[0]
# Out:
# 510

# %%
# 7. What is the lowest price of the house?
# A. 45000 B. 28000 C. 75000 D. 25000 

df['price'].min()
# Out:
# 75000

# %%
# 8. Which zip code area has the cheapest house?
# A. 98000 B. 98022 C. 80000 D. 94500 

df.loc[df['price'].idxmin()]['zipcode']
# Out:
# 98022

# %%
# 9. Which area has the biggest sqft_living? 
# A. 98053 B. 98055 C. 98035 D. None of the above 

df.loc[df['sqft_living'].idxmax()]['zipcode']
# Out:
# 98053

# %%
# 10. In which year the costliest house has been built? 
# A. 2000 B. 1992 C. 1911 D. 1910 

df.loc[df['price'].idxmax()]['yr_built']
# Out:
# 1910

# %%
# 11. Which of the following data types can a Pandas Series have? 
# A. Int B. Str C. Float D. All of the above

#d all the above
# Out:
# dtype('int64')

# %%
df['zipcode'].dtype
# Out:
# dtype('int64')

# %%
df['waterfront'].dtype
# Out:
# dtype('int64')

# %%
# 12. Which of the following is having a one-dimensional array? 
#A. Series data type B. DataFrame data type C. Both of the above D. None of the above 

# Series data type

# %%
# 13. What value will you get on the left side after printing a series format data?
# A. Data
# B. Value
# C. Index
# D. All of the above

# Indexs

# %%
# 14. Which of the following is considered as data in pandas?
# A. Dictionary
# B. Boolean
# C. Nd-array
# D. All of the above

# all the above

# %%
# 15. In what format the keys will get converted into when we convert the dictionary data into data frame format?
# A. Rows
# B. Columns
# C. Indexes
# D. Records

# Columns

# %%
# 16. Write a function to perform the following operation:
# Increase the grade of the house by 1 if the sqft of the house is greater than 0 and less thanequal to 400. 
# If the total sqft of the house is greater than 400, increase the grade of the house by 2.
# After creating the above function, which syntax will be using when using apply function to run
# the above created function in the dataset?

# A. data.apply(your_function_name(arg1))
# B. data.apply_fun(function_name())
# C. data.app(data)
# D. None of the above

# none of the above

def increase_grade(row):
    if row['sqft_living'] > 0 and row['sqft_living'] <= 400:
        return row['grade'] + 1
    elif row['sqft_living'] > 400:
        return row['grade'] + 2
    else:
        return row['grade']

# Using apply function to run the above created function in the dataset
df['new_grade'] = df.apply(increase_grade, axis=1)

# %%
# 17. How to check the duplicate values on id,grade and location?
# A. df.duplicated(subset=['id','zipcode','grade'])
# B. df.duplicate(subset=['id','zipcode','grade'])
# C. df[df.duplicated(['id','zipcode','grade’])]
# D. All of the above

#  A

# df[df.duplicated(['id', 'zipcode', 'grade'])]
# df.duplicated(subset=['id','zipcode','grade'])
# Out:
#                id             date    price  bedrooms  bathrooms  sqft_living  \
# 94     6021501535  20141223T000000   700000         3       1.50         1580
# 314    4139480200  20141209T000000  1400000         4       3.25         4290
# 325    7520000520  20150311T000000   240500         2       1.00         1240
# 346    3969300030  20141229T000000   239900         4       1.00         1000
# 372    2231500030  20150324T000000   530000         4       2.25         2180
# ...           ...              ...      ...       ...        ...          ...
# 20181  7853400250  20150219T000000   645000         4       3.50         2910
# 20613  2724049222  20141201T000000   220000         2       2.50         1000
# 20670  8564860270  20150330T000000   502000         4       2.50         2680
# 20780  6300000226  20150504T000000   380000         4       1.00         1200
# 21581  7853420110  20150504T000000   625000         3       3.00         2780
#
# ...

# %%
# 18. Which of the following code will help to display the 3rd, 4th and 5th rows from the 6th to 9th
# columns of data frame data?
# A. data.loc[3:6, 6:10]
# B. data.iloc[3;6,6;10]
# C. data.iloc[3:6,6:10]
# D. None of the above

# Answer: C. 
df.iloc[3:6, 6:10]
# Out:
#    sqft_lot  floors  waterfront  view
# 3      5000     1.0           0     0
# 4      8080     1.0           0     0
# 5    101930     1.0           0     0

# %%
# 19. Which of the following syntax will display the last two records of df?
# import pandas as pd
# df = pd.DataFrame({'A':[34, 78, 54], 'B':[12, 67, 43]}, index=['r1', 'r2', 'r3'])
# A. df.iloc[:'r3']
# B. df.loc['r2':'r3']
# C. df.iloc['r2':'r3']
# D. df.loc[:'r3']

ddff = pd.DataFrame({'A':[34, 78, 54], 'B':[12, 67, 43]}, index=['r1', 'r2', 'r3'])

# %%
ddff.loc['r2':'r3']
# Out:
#      A   B
# r2  78  67
# r3  54  43

# %%
# 20. Which of the following is/are true about loc in pandas:
# A. Add new rows in the data frames
# B. To change the values of a row to a particular value
# C. To extract values from the particular rows
# D. All of the above

# All of the above

# %%
df.head(2)
# Out:
#            id             date   price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900         3       1.00         1180
# 1  6414100192  20141209T000000  538000         3       2.25         2570
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# 0      1955             0    98178  47.5112 -122.257           1340
# 1      1951          1991    98125  47.7210 -122.319           1690
#
#    sqft_lot15
# 0        5650
# 1        7639
#
# [2 rows x 21 columns]

# %%
# 21) Which of the following is the correct syntax for getting the houses where no. of bedrooms is maximum having 3 views 
# along with 1 waterfront?

# A housing[(housing["bedrooms"]==2) & (housing["view"]==3) & (housing["waterfront"]==1)]
# B None of the Above
# C housing[(housing["bedrooms"]==housing["bedrooms"].max()) & (housing["view"]==3) & (housing["waterfront"]==1)]
# D housing[(housing["bedrooms"]==housing["bedrooms"].mean()) & (housing["view"]==3) & (housing["waterfront"]==1)]

#c
h_ss= df[(df["bedrooms"]==df["bedrooms"].max()) & (df["view"]==3) & (df["waterfront"]==1)]
h_ss
# Out:
# Empty DataFrame
# Columns: [id, date, price, bedrooms, bathrooms, sqft_living, sqft_lot, floors, waterfront, view, condition, grade, sqft_above, sqft_basement, yr_built, yr_renovated, zipcode, lat, long, sqft_living15, sqft_lot15]
# Index: []
#
# [0 rows x 21 columns]

# %%
# 22) Create a separate data frame that satisfies the conditions below. 
# 1. Houses built before 1980 2.Have more than 2 bedrooms 3. Have more than 2 floors.
# A data.loc[(data["yr_built"] < 1980) & (data['floors'] > 2) & (data['bedrooms'] > 2)]
# B data.loc[(data["yr_built"] < 1980) | (data['floors'] > 2) | (data['bedrooms'] < 2)]
# C data.loc[(data["yr_built"] > 1980) & (data['floors'] > 2) & (data['bedrooms'] > 2)]
# D data.loc[(data["yr_built"] | 1980) & (data['floors'] > 2) | (data['bedrooms'] > 2)]

# A
df.loc[(df["yr_built"] < 1980) & (df['floors'] > 2) & (df['bedrooms'] > 2)]
# Out:
#                id             date    price  bedrooms  bathrooms  sqft_living  \
# 518    4386700135  20141114T000000  2250000         4       2.25         4760
# 759     770000045  20141024T000000   405600         5       1.50         2830
# 960    7578200310  20141112T000000   650000         4       2.00         2208
# 1296   5458800125  20140514T000000   925000         4       2.50         2190
# 1350   7234600786  20140511T000000   842500         4       2.50         2160
# ...           ...              ...      ...       ...        ...          ...
# 18535  3667500015  20140925T000000   770000         4       3.50         3680
# 18631  1337800665  20140811T000000  1325000         4       3.25         2850
# 19068  6613001241  20140811T000000  1415000         4       3.00         3110
# 19188  7942601475  20140520T000000   345600         5       3.50         2800
# 19272  1337300145  20140721T000000  1800000         4       2.50         3320
#
# ...

# %%
# 23) For a given nested list, convert the same into a dataframe. 
# sample_list = [['Carl', 22], ['Martha', 25], ['Calvin', 12], ['Stuart', 15] ] 
# The resulting dataframe must contain the column names as ‘Name’, and ‘Age’ with the respective values from the sample_list.
# A pd.DataFrame(sample_list, column_name=['Name', 'Age'])
# B pd.DataFrame(sample_list, columns=['Name', 'Age'])
# C pd.DataFrame(sample_list)
# D pd.DataFrame(sample_list, column_names=['Name', 'Age'])

#b
sample_list = [['Carl', 22], ['Martha', 25], ['Calvin', 12], ['Stuart', 15] ] 
pd.DataFrame(sample_list, columns=['Name', 'Age'])
# Out:
#      Name  Age
# 0    Carl   22
# 1  Martha   25
# 2  Calvin   12
# 3  Stuart   15

# %%
# 24) For a given dictionary, convert the same into a dataframe. 
# sample_dict = {'Cristiano': ['Ronaldo','Man U', 801], 'Lionel': ['Messi','PSG', 758], 
#              'Luis': ['Suarez','Atletico Madrid', 509], 'Robert': ['Lewandowski','Bayern Munich', 527], 'Zlatan': ['Ibrahimovic','AC Milan',553] }
# A df1 = pd.Dataframe(sample_dict) df1 = df1.transpose() df1.reset_index(inplace = True) df1.columns = ['First Name','Last Name', 'Club', 'Goals']
# B df1 = pd.DataFrame(sample_dict) df1 = df1.transpose() df1.reset_index(inplace = True) df1.columns = ['First Name','Last Name', 'Club', 'Goals']
# C df1 = pd.DataFrame(sample_dict) df1.reset_index(inplace = True) df1.columns = ['First Name','Last Name', 'Club', 'Goals']
# D df1 = pd.DataFrame(sample_dict) df1 = df1.transpose() df1.columns = ['First Name','Last Name', 'Club', 'Goals']

# B
#df1 = pd.DataFrame(sample_dict); df1 = df1.transpose() df1.reset_index(inplace=True) df1.columns = ['First Name', 'Last Name', 'Club', 'Goals']

# %%
# 25) For a given tuple, convert the same into a dataframe. 
# sample_tuple = ([1, 'one', 3], [2, 'two', 3], [3, 'Three', 5], [4, 'Four', 4], [5, 'Five', 4])
# A pd.DataFrame(sample_tup, columns=['Number', 'Number_text', 'txtlen'])
# B pd.Dataframe(sample_tuple, columns=['Number', 'Number_text', 'txtlen'])
# C pd.dataframe(sample_tuple, columns=['Number', 'Number_text', 'txtlen'])
# D pd.DataFrame(sample_tuple, columns=['Number', 'Number_text', 'txtlen'])

sample_tuple = ([1, 'one', 3], [2, 'two', 3], [3, 'Three', 5], [4, 'Four', 4], [5, 'Five', 4])
tup_df = pd.DataFrame(sample_tuple, columns=['Number', 'Number_text', 'txtlen'])

# %%
tup_df
# Out:
#    Number Number_text  txtlen
# 0       1         one       3
# 1       2         two       3
# 2       3       Three       5
# 3       4        Four       4
# 4       5        Five       4

# %%
# 26) Create a separate dataframe that contains houses ordered in ascending or descending order of the prices of each house.
# A ascending = housing.sort_values('price', ascending=True) descending = housing.sort_values('price', ascending=False)
# B ascending = housing.sort_values('price', ascending=False) descending = housing.sort_values('price', ascending=True)
# C ascending = housing.sort_values('price', ascending=False) descending = housing.sort_values('price', ascending=False)
# D ascending = housing.sort_values('price', ascending=True) descending = housing.sort_values('price', ascending=True)

#A
#ascending = df.sort_values('price', ascending=True); descending = df.sort_values('price', ascending=False)

# %%
# 27) Calculate the mean and standard deviation of all the numerical values in the dataset. 
# For example - the mean for the bedrooms column is 3.370 and the standard deviation is 0.930.
# A housing.info()
# B housing.describe()
# C housing.std()
# D housing.corr()

# df.describe()

# %%
# 28) Perform the following operations on the pandas dataframe.
# 1. Get the data starting from the indexes 25 to 35.
# 2. Get the price of the houses located at the longitude--122.045 latitude- 47.6168.

# A data[25:35], data.loc[(housing["lat"] == 47.6168) | (data["long"] == -122.045)]
# B data[24:36], data.loc[(housing["lat"] == 47.6168) & (data["long"] == -122.045)]
# C data[24:34], data.loc[(housing["lat"] == 47.6168) & (data["long"] == -122.045)]
# D data[25:36], data.loc[(housing["lat"] == 47.6168) & (data["long"] == -122.045)]

#a
df[25:35], df.loc[(df["lat"] == 47.6168) | (df["long"] == -122.045)]
# Out:
# (            id             date   price  bedrooms  bathrooms  sqft_living  \
#  25  1202000200  20141103T000000  233000         3       2.00         1710
#  26  1794500383  20140626T000000  937000         3       1.75         2450
#  27  3303700376  20141201T000000  667000         3       1.00         1400
#  28  5101402488  20140624T000000  438000         3       1.75         1520
#  29  1873100390  20150302T000000  719000         4       2.50         2570
#  30  8562750320  20141110T000000  580500         3       2.50         2320
#  31  2426039314  20141201T000000  280000         2       1.50         1190
#  32   461000390  20140624T000000  687500         4       1.75         2330
#  33  7589200193  20141110T000000  535000         3       1.00         1090
#  34  7955080270  20141203T000000  322500         4       2.75         2060
#
#      sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# ...

# %%
# 29) Create a new column with the floor area(sqft_living, sqft_lot, sqft_above, sqft_basement, all combined in one column).

# A data['Floor Area'] = data['sqft_living'], data['sqft_lot'], data['sqft_basement'], data['sqft_above']
# B data['Floor Area'] = data['sqft_liv', 'sqft_lot','sqft_base','sqft_above']
# C df['Floor Area'] = data['sqft_living'] + data['sqft_lot'] + data['sqft_basement'] + data['sqft_above']
# D data['Floor Area'] = data['sqft_living', 'sqft_lot','sqft_basement','sqft_above']

# c
df['Floor Area'] = df['sqft_living'] + df['sqft_lot'] + df['sqft_basement'] + df['sqft_above']
df.head(3)
# Out:
#            id             date   price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900         3       1.00         1180
# 1  6414100192  20141209T000000  538000         3       2.25         2570
# 2  5631500400  20150225T000000  180000         2       1.00          770
#
#    sqft_lot  floors  waterfront  view  ...  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...        1180              0
# 1      7242     2.0           0     0  ...        2170            400
# 2     10000     1.0           0     0  ...         770              0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# 0      1955             0    98178  47.5112 -122.257           1340
# 1      1951          1991    98125  47.7210 -122.319           1690
# 2      1933             0    98028  47.7379 -122.233           2720
#
#    sqft_lot15  Floor Area
# 0        5650        8010
# 1        7639       12382
# 2        8062       11540
#
# ...

# %%
# 30) Perform the following operations on the dataframes given below. 
# A = pd.DataFrame([['Carl', 22],['Martha', 25],['Calvin', 12],['Stuart', 15]], columns=[‘Name’, ‘Age’]) 
# B = pd.DataFrame([['Melvin', 25],['Martha', 34],['Lewis', 32],['Leo', 25]], columns=[‘Name’, ‘Age’]) 
# 1. Left Outer Join 2. Outer Join 3. Inner Join 4. Right Outer Join


# inner = pd.merge(A, B, on='Age', how='inner') outer = pd.merge(A, B, on='Age', how='outer') left_outer = pd.merge(A, B, on='Age', how='left') right_outer = pd.merge(A, B, on='Age', how='right')
# inner = pd.merge(A, B, on='Age', how='inner') outer = pd.merge(A, B, on='Age', how='outer') left_outer = pd.merge(A, B, on='Age', how='outer_left') right_outer = pd.merge(A, B, on='Age', how='outer_right')
# inner = pd.merge(A, B, on='Age', how='inner_join') outer = pd.merge(A, B, on='Age', how='outer_join') left_outer = pd.merge(A, B, on='Age', how='left_join') right_outer = pd.merge(A, B, on='Age', how='right_join')
# inner = pd.merge(A, B, on='Age', how='inner') outer = pd.merge(A, B, on='Age', how='outer') left_outer = pd.merge(A, B, on='Age', how='left_outer')

# %%
# 31) What will be the correlation between the columns sqft_living and sqft_above?
# A 0.754665
# B 0.702035
# C 0.303093
# D 0.876597

#  d
corr = df['sqft_living'].corr(df['sqft_above'])
print(corr)
# Out:
# 0.876596598681317

# %%
# 32) If the correlation between the columns bathrooms and sqft_living is 0.754665, 
# what all interpretations can be made about the two columns?

# A No correlation between the two columns.
# B The columns show perfect correlation.
# C A positive correlation between the two columns
# D A strong negative correlation between the two columns

# A positive correlation between the two columns

# %%
# 6. How many houses have 3 views? 
# A. 340 B. 550 C. 510 D. 90 

df[df['view'] == 3].shape[0]
#df[df['view'] == 3].sum()     
                                    #.shape[0]
# Out:
# 510

# %%
# 5. Does this 9126100861 customer have a waterfront? A. Yes B. No 

df_wf = 'Yes' if df[df['id'] == 9126100861]['waterfront'].values[0] == 1 else 'No'
df_wf                       
                                         #waterfront
# Out:
# 'No'

# %%
# 6. How many houses have 3 views? 
# A. 340 B. 550 C. 510 D. 90 

#df[df['view'] == 3].shape[0]
#df['view'] == 3                              #df[df]

# %%
# 8. Which zip code area has the cheapest house?
# A. 98000 B. 98022 C. 80000 D. 94500 

# df.loc[df['price'].idxmin()]['zipcode']                 
                                                     # loc, idx

# %%
# 17. How to check the duplicate values on id,grade and location?
# A. df.duplicated(subset=['id','zipcode','grade'])
# B. df.duplicate(subset=['id','zipcode','grade'])
# C. df[df.duplicated(['id','zipcode','grade’])]
# D. All of the above

# df[df.duplicated(['id', 'zipcode', 'grade'])]
# df.duplicated(subset=['id','zipcode','grade'])

# %%
# 24) For a given dictionary, convert the same into a dataframe. 
# sample_dict = {'Cristiano': ['Ronaldo','Man U', 801], 'Lionel': ['Messi','PSG', 758], 
#              'Luis': ['Suarez','Atletico Madrid', 509], 'Robert': ['Lewandowski','Bayern Munich', 527], 'Zlatan': ['Ibrahimovic','AC Milan',553] }
# A df1 = pd.Dataframe(sample_dict) df1 = df1.transpose() df1.reset_index(inplace = True) df1.columns = ['First Name','Last Name', 'Club', 'Goals']
# B df1 = pd.DataFrame(sample_dict) df1 = df1.transpose() df1.reset_index(inplace = True) df1.columns = ['First Name','Last Name', 'Club', 'Goals']
# C df1 = pd.DataFrame(sample_dict) df1.reset_index(inplace = True) df1.columns = ['First Name','Last Name', 'Club', 'Goals']
# D df1 = pd.DataFrame(sample_dict) df1 = df1.transpose() df1.columns = ['First Name','Last Name', 'Club', 'Goals']
